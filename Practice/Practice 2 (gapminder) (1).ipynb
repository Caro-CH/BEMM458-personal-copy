# %% [markdown]
# #importing libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %% [markdown]
# load the data set:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %% [markdown]
# Explore the dataset

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %% [markdown]
# explore using groupby

# %%
df.groupby('country')['gdpPercap'].mean()
# Out:
# country
# Afghanistan            802.674598
# Albania               3255.366633
# Algeria               4426.025973
# Angola                3607.100529
# Argentina             8955.553783
#                          ...
# Vietnam               1017.712615
# West Bank and Gaza    3759.996781
# Yemen, Rep.           1569.274672
# Zambia                1358.199409
# Zimbabwe               635.858042
# Name: gdpPercap, Length: 142, dtype: float64

# %%
df.groupby('country')['gdpPercap'].max()
# Out:
# country
# Afghanistan             978.011439
# Albania                5937.029526
# Algeria                6223.367465
# Angola                 5522.776375
# Argentina             12779.379640
#                           ...
# Vietnam                2441.576404
# West Bank and Gaza     7110.667619
# Yemen, Rep.            2280.769906
# Zambia                 1777.077318
# Zimbabwe                799.362176
# Name: gdpPercap, Length: 142, dtype: float64

# %%
df.groupby('country')['gdpPercap','pop'].max()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        gdpPercap       pop
# country
# Afghanistan           978.011439  31889923
# Albania              5937.029526   3600523
# Algeria              6223.367465  33333216
# Angola               5522.776375  12420476
# Argentina           12779.379640  40301927
# ...                          ...       ...
# Vietnam              2441.576404  85262356
# West Bank and Gaza   7110.667619   4018332
# Yemen, Rep.          2280.769906  22211743
# Zambia               1777.077318  11746035
# Zimbabwe              799.362176  12311143
#
# [142 rows x 2 columns]

# %%
gapmindercountryMax=df.groupby('country')['pop'].max()

# %%
gapmindercountryMax
# Out:
# country
# Afghanistan           31889923
# Albania                3600523
# Algeria               33333216
# Angola                12420476
# Argentina             40301927
#                         ...
# Vietnam               85262356
# West Bank and Gaza     4018332
# Yemen, Rep.           22211743
# Zambia                11746035
# Zimbabwe              12311143
# Name: pop, Length: 142, dtype: int64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
sns.barplot(gapmindercountryMax)

# %% [markdown]
# having issues with plotting, will try to plot different variables

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# filter dataset to include only most recent measurements

# %%
gapminder2007filter=df['year']==2007

# %%
gapminder2007=df[gapminder2007filter]

# %%
gapminder2007
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
# [142 rows x 6 columns]

# %%
gapminder2007.groupby('continent').mean()
# Out:
#              year    lifeExp           pop     gdpPercap
# continent
# Africa     2007.0  54.806038  1.787576e+07   3089.032605
# Americas   2007.0  73.608120  3.595485e+07  11003.031625
# Asia       2007.0  70.728485  1.155138e+08  12473.026870
# Europe     2007.0  77.648600  1.953662e+07  25054.481636
# Oceania    2007.0  80.719500  1.227497e+07  29810.188275

# %%
sns.scatterplot(data=gapminder2007,x='gdpPercap', y='lifeExp',hue='continent')

# %% [markdown]
# having issues with seaborn, but unsure how to uninstall and install newest version

# %%
sns.set_theme(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-bcdee8ede155> in <module>
# ----> 1 sns.set_theme(style="whitegrid")
#
# AttributeError: module 'seaborn' has no attribute 'set_theme'
