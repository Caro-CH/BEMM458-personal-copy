# %%
import pandas as pd

# %%
gapminder = pd.read_csv('https://raw.githubusercontent.com/Caro-CH/BEMM458-personal-copy/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
Airquality= pd.read_csv('https://raw.githubusercontent.com/Caro-CH/BEMM458-personal-copy/master/data/air_quality_no2_long.csv')

# %%
Airquality
# Out:
#         city country                   date.utc            location parameter  \
# 0      Paris      FR  2019-06-21 00:00:00+00:00             FR04014       no2
# 1      Paris      FR  2019-06-20 23:00:00+00:00             FR04014       no2
# 2      Paris      FR  2019-06-20 22:00:00+00:00             FR04014       no2
# 3      Paris      FR  2019-06-20 21:00:00+00:00             FR04014       no2
# 4      Paris      FR  2019-06-20 20:00:00+00:00             FR04014       no2
# ...      ...     ...                        ...                 ...       ...
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
#       value   unit
# ...

# %%
Airquality.groupby('city')['value'].mean()
# Out:
# city
# Antwerpen    25.778947
# London       24.777090
# Paris        27.740538
# Name: value, dtype: float64

# %%
Airquality.info
# Out:
# <bound method DataFrame.info of         city country                   date.utc            location parameter  \
# 0      Paris      FR  2019-06-21 00:00:00+00:00             FR04014       no2
# 1      Paris      FR  2019-06-20 23:00:00+00:00             FR04014       no2
# 2      Paris      FR  2019-06-20 22:00:00+00:00             FR04014       no2
# 3      Paris      FR  2019-06-20 21:00:00+00:00             FR04014       no2
# 4      Paris      FR  2019-06-20 20:00:00+00:00             FR04014       no2
# ...      ...     ...                        ...                 ...       ...
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
# ...

# %%
Airquality.dtypes
# Out:
# city          object
# country       object
# date.utc      object
# location      object
# parameter     object
# value        float64
# unit          object
# dtype: object

# %%
Airquality['Date']=pd.to_datetime(Airquality['date.utc'])

# %% [markdown]
# #Conversion to date time is not possible, potentially due to issues in formatting?

# %%
Airquality['Date']=pd.to_datetime(Airquality['Date.utc'],errors:str='coerce')
# Out:
#   File "<ipython-input-12-a04154965dec>", line 1
#     Airquality['Date']=pd.to_datetime(Airquality['Date.utc'],errors:str='coerce')
#                                                                    ^
# SyntaxError: invalid syntax

# %%
Airquality

# %%
dictionaryOfScientists={'Name': ['Rosaline Franklin', 'William Gosset','Alexander Flemming','Carl F. Gauss'],
                        'Occupation': ['Chemist', 'Statistician','Physician','Mathematician'],
                        'Born': ['1920-07-25', '1876-06-13','1881-08-06','1777-04-10'],
                        'Died': ['1958-04-16', '1937-10-16','1954-03-11','1855-02-23'],
                        'Age': [37, 61,73,77]}

# %%
df=pd.DataFrame(dictionaryOfScientists)

# %%
df
# Out:
#                  Name     Occupation        Born        Died  Age
# 0   Rosaline Franklin        Chemist  1920-07-25  1958-04-16   37
# 1      William Gosset   Statistician  1876-06-13  1937-10-16   61
# 2  Alexander Flemming      Physician  1881-08-06  1954-03-11   73
# 3       Carl F. Gauss  Mathematician  1777-04-10  1855-02-23   77

# %%
df.dtypes
# Out:
# Name          object
# Occupation    object
# Born          object
# Died          object
# Age            int64
# dtype: object

# %%
Airquality
# Out:
#         city country                   date.utc            location parameter  \
# 0      Paris      FR  2019-06-21 00:00:00+00:00             FR04014       no2
# 1      Paris      FR  2019-06-20 23:00:00+00:00             FR04014       no2
# 2      Paris      FR  2019-06-20 22:00:00+00:00             FR04014       no2
# 3      Paris      FR  2019-06-20 21:00:00+00:00             FR04014       no2
# 4      Paris      FR  2019-06-20 20:00:00+00:00             FR04014       no2
# ...      ...     ...                        ...                 ...       ...
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
# ...

# %%
AirqualityLondon=Airquality['city']=='London'

# %%
Airquality[AirqualityLondon]
# Out:
#         city country                   date.utc            location parameter  \
# 1099  London      GB  2019-06-17 11:00:00+00:00  London Westminster       no2
# 1100  London      GB  2019-06-17 10:00:00+00:00  London Westminster       no2
# 1101  London      GB  2019-06-17 09:00:00+00:00  London Westminster       no2
# 1102  London      GB  2019-06-17 08:00:00+00:00  London Westminster       no2
# 1103  London      GB  2019-06-17 07:00:00+00:00  London Westminster       no2
# ...      ...     ...                        ...                 ...       ...
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
# ...

# %% [raw]
# Airquality[AirqualityLondon].plot(x="Date", y="value")

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
ax=sns.lineplot(x="Date", y="value", data=Airquality)

# %%
ax=sns.lineplot(x="Date", y="value", data=Airquality[AirqualityLondon])

# %%
ax=sns.lineplot(x="Date", y="value",hue="city", data=Airquality)

# %%
ax=sns.barplot(x="Date", y="value",hue="city", data=Airquality)
